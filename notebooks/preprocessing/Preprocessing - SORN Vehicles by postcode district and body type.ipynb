# %%
! python3 --version
# Out:
# Python 3.8.12

# %%
import pandas as pd
import numpy as np
import os
import re
import functools

pd.__version__, np.__version__
# Out:
# ('1.4.1', '1.21.2')

# %%
project_dir = '/Users/gurdeep/Documents/tb2/DSMP/G32-Butterfly-Data'
module_dir = project_dir+'/modules'

dataset_filepath = '/Users/gurdeep/Documents/tb2/DSMP/Vehicles with a Statutory Off Road Notification by postcode district and body type United Kingdom.xlsx'

os.chdir(project_dir)
current_working_dir = os.getcwd()
print("Current working dir:", current_working_dir)
print("All paths correct:", os.path.isdir(project_dir) == os.path.isdir(module_dir) == os.path.isfile(dataset_filepath) == True)
# Out:
# Current working dir: /Users/gurdeep/Documents/tb2/DSMP/G32-Butterfly-Data
# All paths correct: True

# %%
# importing preprocessing module
os.chdir(module_dir)
import Preprocessing
os.chdir(current_working_dir)

# %% [markdown]
# ## Loading File

# %%
extract_configs = [
        {'io': dataset_filepath, 'sheet_name':'2021', 'header':[0,1], 'skiprows':6, 'skipfooter':13},
        {'io': dataset_filepath, 'sheet_name':'2020', 'header':[0,1], 'skiprows':6, 'skipfooter':13},
        {'io': dataset_filepath, 'sheet_name':'2019', 'header':[0,1], 'skiprows':6, 'skipfooter':13},
        {'io': dataset_filepath, 'sheet_name':'2018', 'header':[0,1], 'skiprows':6, 'skipfooter':12},
        {'io': dataset_filepath, 'sheet_name':'2017', 'header':[0,1], 'skiprows':6, 'skipfooter':8},
        {'io': dataset_filepath, 'sheet_name':'2016', 'header':[0,1], 'skiprows':6, 'skipfooter':9},
        {'io': dataset_filepath, 'sheet_name':'2015', 'header':[0,1], 'skiprows':6, 'skipfooter':9},
        {'io': dataset_filepath, 'sheet_name':'2014', 'header':[0,1], 'skiprows':6, 'skipfooter':10},
    ]

# %%
dfs = {
    config['sheet_name']:pd.read_excel(**config) for config in extract_configs
}

for sheet_name, df in dfs.items():
    print(sheet_name, "\n")
    df.info()
    print("\n"+"-"*50+"\n")
# Out:
# 2021
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2884 entries, 0 to 2883
# Data columns (total 12 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2884 non-null   object
#  1   (2021 Q1 , Cars)                         2880 non-null   object
#  2   (2021 Q1 , Motorcycles)                  2880 non-null   object
#  3   (2021 Q1 , All others)                   2880 non-null   object
#  4   (2021 Q1 , All others.1)                 0 non-null      float64
#  5   (2021 Q2, Cars)                          2881 non-null   object
#  6   (2021 Q2, Motorcycles)                   2881 non-null   object
#  7   (2021 Q2, All others)                    2881 non-null   object
#  8   (2021 Q2, All others.1)                  0 non-null      float64
#  9   (2021 Q3, Cars)                          2882 non-null   object
#  10  (2021 Q3, Motorcycles)                   2882 non-null   object
#  11  (2021 Q3, All others)                    2882 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 270.5+ KB
#
# --------------------------------------------------
#
# 2020
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2882 entries, 0 to 2881
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2882 non-null   object
#  1   (2020 Q1 , Cars)                         2879 non-null   object
#  2   (2020 Q1 , Motorcycles)                  2879 non-null   object
#  3   (2020 Q1 , All others)                   2879 non-null   object
#  4   (2020 Q1 , All others.1)                 0 non-null      float64
#  5   (2020 Q2, Cars)                          2878 non-null   object
#  6   (2020 Q2, Motorcycles)                   2878 non-null   object
#  7   (2020 Q2, All others)                    2878 non-null   object
#  8   (2020 Q2, All others.1)                  0 non-null      float64
#  9   (2020 Q3, Cars)                          2877 non-null   object
#  10  (2020 Q3, Motorcycles)                   2877 non-null   object
#  11  (2020 Q3, All others)                    2877 non-null   object
#  12  (2020 Q3, All others.1)                  0 non-null      float64
#  13  (2020 Q4, Cars)                          2879 non-null   object
#  14  (2020 Q4, Motorcycles)                   2879 non-null   object
#  15  (2020 Q4, All others)                    2879 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 360.4+ KB
#
# --------------------------------------------------
#
# 2019
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2880 non-null   object
#  1   (2019 Q1, Cars)                          2877 non-null   object
#  2   (2019 Q1, Motorcycles)                   2877 non-null   object
#  3   (2019 Q1, All others)                    2877 non-null   object
#  4   (2019 Q1, All others.1)                  0 non-null      float64
#  5   (2019 Q2, Cars)                          2876 non-null   object
#  6   (2019 Q2, Motorcycles)                   2876 non-null   object
#  7   (2019 Q2, All others)                    2876 non-null   object
#  8   (2019 Q2, All others.1)                  0 non-null      float64
#  9   (2019 Q3, Cars)                          2875 non-null   object
#  10  (2019 Q3, Motorcycles)                   2875 non-null   object
#  11  (2019 Q3, All others)                    2875 non-null   object
#  12  (2019 Q3, All others.1)                  0 non-null      float64
#  13  (2019 Q4, Cars)                          2878 non-null   object
#  14  (2019 Q4, Motorcycles)                   2878 non-null   object
#  15  (2019 Q4, All others)                    2878 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 360.1+ KB
#
# --------------------------------------------------
#
# 2018
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2880 non-null   object
#  1   (2018 Q1, Cars)                          2877 non-null   object
#  2   (2018 Q1, Motorcycles)                   2877 non-null   object
#  3   (2018 Q1, All others)                    2877 non-null   object
#  4   (2018 Q1, All others.1)                  0 non-null      float64
#  5   (2018 Q2, Cars)                          2876 non-null   object
#  6   (2018 Q2, Motorcycles)                   2876 non-null   object
#  7   (2018 Q2, All others)                    2876 non-null   object
#  8   (2018 Q2, All others.1)                  0 non-null      float64
#  9   (2018 Q3, Cars)                          2877 non-null   object
#  10  (2018 Q3, Motorcycles)                   2877 non-null   object
#  11  (2018 Q3, All others)                    2877 non-null   object
#  12  (2018 Q3, All others.1)                  0 non-null      float64
#  13  (2018 Q4, Cars)                          2875 non-null   object
#  14  (2018 Q4, Motorcycles)                   2875 non-null   object
#  15  (2018 Q4, All others)                    2875 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 360.1+ KB
#
# --------------------------------------------------
#
# 2017
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2880 non-null   object
#  1   (2017 Q1, Cars)                          2870 non-null   object
#  2   (2017 Q1, Motorcycles)                   2870 non-null   object
#  3   (2017 Q1, All others)                    2870 non-null   object
#  4   (2017 Q1, All others.1)                  0 non-null      float64
#  5   (2017 Q2, Cars)                          2872 non-null   object
#  6   (2017 Q2, Motorcycles)                   2872 non-null   object
#  7   (2017 Q2, All others)                    2872 non-null   object
#  8   (2017 Q2, All others.1)                  0 non-null      float64
#  9   (2017 Q3, Cars)                          2874 non-null   object
#  10  (2017 Q3, Motorcycles)                   2874 non-null   object
#  11  (2017 Q3, All others)                    2874 non-null   object
#  12  (2017 Q3, All others.1)                  0 non-null      float64
#  13  (2017 Q4, Cars)                          2876 non-null   object
#  14  (2017 Q4, Motorcycles)                   2876 non-null   object
#  15  (2017 Q4, All others)                    2876 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 360.1+ KB
#
# --------------------------------------------------
#
# 2016
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2875 entries, 0 to 2874
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2875 non-null   object
#  1   (2016 Q1, Cars)                          2868 non-null   object
#  2   (2016 Q1, Motorcycles)                   2868 non-null   object
#  3   (2016 Q1, All others)                    2868 non-null   object
#  4   (2016 Q1, All others.1)                  0 non-null      float64
#  5   (2016 Q2, Cars)                          2868 non-null   object
#  6   (2016 Q2, Motorcycles)                   2868 non-null   object
#  7   (2016 Q2, All others)                    2868 non-null   object
#  8   (2016 Q2, All others.1)                  0 non-null      float64
#  9   (2016 Q3, Cars)                          2870 non-null   object
#  10  (2016 Q3, Motorcycles)                   2870 non-null   object
#  11  (2016 Q3, All others)                    2870 non-null   object
#  12  (2016 Q3, All others.1)                  0 non-null      float64
#  13  (2016 Q4, Cars)                          2871 non-null   object
#  14  (2016 Q4, Motorcycles)                   2871 non-null   object
#  15  (2016 Q4, All others)                    2871 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 359.5+ KB
#
# --------------------------------------------------
#
# 2015
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2873 entries, 0 to 2872
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2873 non-null   object
#  1   (2015 Q1, Cars)                          2865 non-null   object
#  2   (2015 Q1, Motorcycles)                   2865 non-null   object
#  3   (2015 Q1, All others)                    2865 non-null   object
#  4   (2015 Q1, All others.1)                  0 non-null      float64
#  5   (2015 Q2, Cars)                          2866 non-null   object
#  6   (2015 Q2, Motorcycles)                   2866 non-null   object
#  7   (2015 Q2, All others)                    2866 non-null   object
#  8   (2015 Q2, All others.1)                  0 non-null      float64
#  9   (2015 Q3, Cars)                          2866 non-null   object
#  10  (2015 Q3, Motorcycles)                   2866 non-null   object
#  11  (2015 Q3, All others)                    2866 non-null   object
#  12  (2015 Q3, All others.1)                  0 non-null      float64
#  13  (2015 Q4, Cars)                          2867 non-null   object
#  14  (2015 Q4, Motorcycles)                   2867 non-null   object
#  15  (2015 Q4, All others)                    2867 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 359.2+ KB
#
# --------------------------------------------------
#
# 2014
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2868 entries, 0 to 2867
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, Postcode District)  2868 non-null   object
#  1   (2014 Q1, Cars)                          2779 non-null   object
#  2   (2014 Q1, Motorcycles)                   2779 non-null   object
#  3   (2014 Q1, All others)                    2779 non-null   object
#  4   (2014 Q1, All others.1)                  0 non-null      float64
#  5   (2014 Q2, Cars)                          2778 non-null   object
#  6   (2014 Q2, Motorcycles)                   2778 non-null   object
#  7   (2014 Q2, All others)                    2778 non-null   object
#  8   (2014 Q2, All others.1)                  0 non-null      float64
#  9   (2014 Q3, Cars)                          2859 non-null   object
#  10  (2014 Q3, Motorcycles)                   2859 non-null   object
#  11  (2014 Q3, All others)                    2859 non-null   object
#  12  (2014 Q3, All others.1)                  0 non-null      float64
#  13  (2014 Q4, Cars)                          2865 non-null   object
#  14  (2014 Q4, Motorcycles)                   2865 non-null   object
#  15  (2014 Q4, All others)                    2865 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 358.6+ KB
#
# --------------------------------------------------

# %% [markdown]
# ## Renaming columns

# %%
def multiIndexRenameMapper(column_names: pd.MultiIndex):
    assert isinstance(column_names, pd.MultiIndex)
    mapper = {}
    for col in column_names:
        assert isinstance(col, tuple)
        assert len(col) == 2
        if any(['Postcode' in c for c in col]): 
            mapper[col] = "_".join(col[-1].strip().lower().split(" "))
        else:
            first, second = col[0].strip().lower().split(" "), col[1].strip().lower().split(" ")
            assert len(first) == 2
            assert len(second) in [1,2]
            first = first[-1] # just taking quarter and ignoring year
            
            if len(second) == 2 and "all" in second[0] and "others" in second[1]:
                second = second[1] # if r'all others*' is present then take only r'others*' as second
            else:
                second = "".join(second)
                
            mapper[col] = first + "_" + second

    return mapper

def renameDataFrame(df: pd.DataFrame, year):
    assert isinstance(df, pd.DataFrame)
    mapper = multiIndexRenameMapper(df.columns)
    new_df = pd.DataFrame()
    
    for prev_col, new_col in mapper.items():
        new_df[new_col] = df[prev_col]
    
    new_df['year'] = year    
    return new_df

# %%
dfs = {year: renameDataFrame(dfs[year], year) for year in dfs.keys()}

for sheet_name, df in dfs.items():
    print(sheet_name, "\n")
    df.info()
    print("\n"+"-"*50+"\n")
# Out:
# 2021
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2884 entries, 0 to 2883
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2884 non-null   object
#  1   q1_cars            2880 non-null   object
#  2   q1_motorcycles     2880 non-null   object
#  3   q1_others          2880 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2881 non-null   object
#  6   q2_motorcycles     2881 non-null   object
#  7   q2_others          2881 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2882 non-null   object
#  10  q3_motorcycles     2882 non-null   object
#  11  q3_others          2882 non-null   object
#  12  year               2884 non-null   object
# dtypes: float64(2), object(11)
# memory usage: 293.0+ KB
#
# --------------------------------------------------
#
# 2020
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2882 entries, 0 to 2881
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2882 non-null   object
#  1   q1_cars            2879 non-null   object
#  2   q1_motorcycles     2879 non-null   object
#  3   q1_others          2879 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2878 non-null   object
#  6   q2_motorcycles     2878 non-null   object
#  7   q2_others          2878 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2877 non-null   object
#  10  q3_motorcycles     2877 non-null   object
#  11  q3_others          2877 non-null   object
#  12  q3_others.1        0 non-null      float64
#  13  q4_cars            2879 non-null   object
#  14  q4_motorcycles     2879 non-null   object
#  15  q4_others          2879 non-null   object
#  16  year               2882 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 382.9+ KB
#
# --------------------------------------------------
#
# 2019
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2880 non-null   object
#  1   q1_cars            2877 non-null   object
#  2   q1_motorcycles     2877 non-null   object
#  3   q1_others          2877 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2876 non-null   object
#  6   q2_motorcycles     2876 non-null   object
#  7   q2_others          2876 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2875 non-null   object
#  10  q3_motorcycles     2875 non-null   object
#  11  q3_others          2875 non-null   object
#  12  q3_others.1        0 non-null      float64
#  13  q4_cars            2878 non-null   object
#  14  q4_motorcycles     2878 non-null   object
#  15  q4_others          2878 non-null   object
#  16  year               2880 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 382.6+ KB
#
# --------------------------------------------------
#
# 2018
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2880 non-null   object
#  1   q1_cars            2877 non-null   object
#  2   q1_motorcycles     2877 non-null   object
#  3   q1_others          2877 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2876 non-null   object
#  6   q2_motorcycles     2876 non-null   object
#  7   q2_others          2876 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2877 non-null   object
#  10  q3_motorcycles     2877 non-null   object
#  11  q3_others          2877 non-null   object
#  12  q3_others.1        0 non-null      float64
#  13  q4_cars            2875 non-null   object
#  14  q4_motorcycles     2875 non-null   object
#  15  q4_others          2875 non-null   object
#  16  year               2880 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 382.6+ KB
#
# --------------------------------------------------
#
# 2017
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2880 non-null   object
#  1   q1_cars            2870 non-null   object
#  2   q1_motorcycles     2870 non-null   object
#  3   q1_others          2870 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2872 non-null   object
#  6   q2_motorcycles     2872 non-null   object
#  7   q2_others          2872 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2874 non-null   object
#  10  q3_motorcycles     2874 non-null   object
#  11  q3_others          2874 non-null   object
#  12  q3_others.1        0 non-null      float64
#  13  q4_cars            2876 non-null   object
#  14  q4_motorcycles     2876 non-null   object
#  15  q4_others          2876 non-null   object
#  16  year               2880 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 382.6+ KB
#
# --------------------------------------------------
#
# 2016
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2875 entries, 0 to 2874
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2875 non-null   object
#  1   q1_cars            2868 non-null   object
#  2   q1_motorcycles     2868 non-null   object
#  3   q1_others          2868 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2868 non-null   object
#  6   q2_motorcycles     2868 non-null   object
#  7   q2_others          2868 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2870 non-null   object
#  10  q3_motorcycles     2870 non-null   object
#  11  q3_others          2870 non-null   object
#  12  q3_others.1        0 non-null      float64
#  13  q4_cars            2871 non-null   object
#  14  q4_motorcycles     2871 non-null   object
#  15  q4_others          2871 non-null   object
#  16  year               2875 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 382.0+ KB
#
# --------------------------------------------------
#
# 2015
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2873 entries, 0 to 2872
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2873 non-null   object
#  1   q1_cars            2865 non-null   object
#  2   q1_motorcycles     2865 non-null   object
#  3   q1_others          2865 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2866 non-null   object
#  6   q2_motorcycles     2866 non-null   object
#  7   q2_others          2866 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2866 non-null   object
#  10  q3_motorcycles     2866 non-null   object
#  11  q3_others          2866 non-null   object
#  12  q3_others.1        0 non-null      float64
#  13  q4_cars            2867 non-null   object
#  14  q4_motorcycles     2867 non-null   object
#  15  q4_others          2867 non-null   object
#  16  year               2873 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 381.7+ KB
#
# --------------------------------------------------
#
# 2014
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2868 entries, 0 to 2867
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  2868 non-null   object
#  1   q1_cars            2779 non-null   object
#  2   q1_motorcycles     2779 non-null   object
#  3   q1_others          2779 non-null   object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            2778 non-null   object
#  6   q2_motorcycles     2778 non-null   object
#  7   q2_others          2778 non-null   object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            2859 non-null   object
#  10  q3_motorcycles     2859 non-null   object
#  11  q3_others          2859 non-null   object
#  12  q3_others.1        0 non-null      float64
#  13  q4_cars            2865 non-null   object
#  14  q4_motorcycles     2865 non-null   object
#  15  q4_others          2865 non-null   object
#  16  year               2868 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 381.0+ KB
#
# --------------------------------------------------

# %% [markdown]
# ## Merging All dataframes

# %%
print("Expected dataframe length after concat:", sum([df.shape[0] for df in dfs.values()]))
# Out:
# Expected dataframe length after concat: 23022

# %%
df = pd.concat(list(dfs.values())) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23022 entries, 0 to 2867
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postcode_district  23022 non-null  object
#  1   q1_cars            22895 non-null  object
#  2   q1_motorcycles     22895 non-null  object
#  3   q1_others          22895 non-null  object
#  4   q1_others.1        0 non-null      float64
#  5   q2_cars            22895 non-null  object
#  6   q2_motorcycles     22895 non-null  object
#  7   q2_others          22895 non-null  object
#  8   q2_others.1        0 non-null      float64
#  9   q3_cars            22980 non-null  object
#  10  q3_motorcycles     22980 non-null  object
#  11  q3_others          22980 non-null  object
#  12  year               23022 non-null  object
#  13  q3_others.1        0 non-null      float64
#  14  q4_cars            20111 non-null  object
#  15  q4_motorcycles     20111 non-null  object
#  16  q4_others          20111 non-null  object
# dtypes: float64(3), object(14)
# memory usage: 3.2+ MB

# %%
df.head()
# Out:
#   postcode_district q1_cars q1_motorcycles q1_others  q1_others.1 q2_cars  \
# 0               AB1      23             12         7          NaN      23
# 1              AB10     519            235        93          NaN     489
# 2              AB11     550            212       187          NaN     555
# 3              AB12    1175            467       720          NaN    1183
# 4              AB13     143             51        28          NaN     136
#
#   q2_motorcycles q2_others  q2_others.1 q3_cars q3_motorcycles q3_others  \
# 0             11         7          NaN      23             11         8
# 1            219        94          NaN     483            226        93
# 2            203       176          NaN     540            199       178
# 3            427       724          NaN    1139            454       705
# 4             51        29          NaN     132             52        25
#
#    year  q3_others.1 q4_cars q4_motorcycles q4_others
# 0  2021          NaN     NaN            NaN       NaN
# 1  2021          NaN     NaN            NaN       NaN
# 2  2021          NaN     NaN            NaN       NaN
# 3  2021          NaN     NaN            NaN       NaN
# 4  2021          NaN     NaN            NaN       NaN

# %% [markdown]
# ## Rebuilding DataFrame

# %%
def DataframeSplits(on:[str], columns):
    splits = []
    for reg_str in on:
        splits.append(list(filter(lambda s: re.match(reg_str, s), columns)))
    return splits

def processDataFrames(df, mapper, quarter):
    df = pd.DataFrame(df)
    df.rename(columns=mapper, inplace=True)
    df['quarter'] = quarter
    return df

def rebuildDataFrame(df, on):
    # findind columns names of each slice of dataframe
    splits = DataframeSplits(on, df.columns.tolist())
    rename_mappers = [(cols[0][1], {c: c.split("_")[-1] for c in cols}) for cols in splits]
    remaining_cols = list(set(df.columns.tolist()) - set(functools.reduce(lambda a,b: a+b, splits)))
    splits = [split+remaining_cols for split in splits]
    
    # renaming each dataframe
    dfs = [processDataFrames(df[cols], mapper[1], mapper[0]) for cols, mapper in zip(splits, rename_mappers)]
    
    # concatenating all dfs
    return pd.concat(dfs).reset_index(drop=True)
    

# chekcing rebuilt dataframe with count of each year
rebuildDataFrame(df, ['^q1', '^q2', '^q3', '^q4']).groupby(['year', 'quarter'])['postcode_district'].agg(['count'])
# Out:
#               count
# year quarter
# 2014 1         2868
#      2         2868
#      3         2868
#      4         2868
# 2015 1         2873
#      2         2873
#      3         2873
#      4         2873
# 2016 1         2875
#      2         2875
#      3         2875
#      4         2875
# 2017 1         2880
#      2         2880
#      3         2880
#      4         2880
# 2018 1         2880
#      2         2880
#      3         2880
#      4         2880
# 2019 1         2880
#      2         2880
#      3         2880
#      4         2880
# 2020 1         2882
#      2         2882
#      3         2882
#      4         2882
# 2021 1         2884
#      2         2884
#      3         2884
#      4         2884

# %%
df = rebuildDataFrame(df, ['^q1', '^q2', '^q3', '^q4'])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92088 entries, 0 to 92087
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cars               88881 non-null  object
#  1   motorcycles        88881 non-null  object
#  2   others             88881 non-null  object
#  3   others.1           0 non-null      float64
#  4   postcode_district  92088 non-null  object
#  5   year               92088 non-null  object
#  6   quarter            92088 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 4.9+ MB
#    cars motorcycles others  others.1 postcode_district  year quarter
# 0    23          12      7       NaN               AB1  2021       1
# 1   519         235     93       NaN              AB10  2021       1
# 2   550         212    187       NaN              AB11  2021       1
# 3  1175         467    720       NaN              AB12  2021       1
# 4   143          51     28       NaN              AB13  2021       1

# %% [markdown]
# ## NaN Values

# %%
nan = Preprocessing.NanAnalyzer(df)
nan.printNaNInfo()
# Out:
# NAN INFO IN THE DATASET:
#
# No of columns with only NaN values: 1
# Column list with only NaN values:
# ['others.1']
#
# No of columns with partial NaN values: 3
# Column list with partial NaN values:
# ['cars', 'motorcycles', 'others']
#
# No of columns with no NaN values: 3
# Column list with no NaN values:
# ['postcode_district', 'year', 'quarter']
#
# Total Values in dataset: 644616
#
# Total NaN Values in the dataset: 101709
#
# Total Partial NaN Values in the dataset: 9621
#
# Partial NaN Values Info:
#        Columns  Partial_NaN_Count  NaN_Vals_By_Total_Vals
# 0         cars               3207                   0.035
# 1  motorcycles               3207                   0.035
# 2       others               3207                   0.035
#
# Total NaN Values/Total Datset Values: 15.78 %

# %%
df.drop(columns=nan.getDict()['only_nan_cols'], inplace=True)

# %%
nan = Preprocessing.NanAnalyzer(df)
nan.printNaNInfo()
# Out:
# NAN INFO IN THE DATASET:
#
# No of columns with only NaN values: 0
# Column list with only NaN values:
# []
#
# No of columns with partial NaN values: 3
# Column list with partial NaN values:
# ['cars', 'motorcycles', 'others']
#
# No of columns with no NaN values: 3
# Column list with no NaN values:
# ['postcode_district', 'year', 'quarter']
#
# Total Values in dataset: 552528
#
# Total NaN Values in the dataset: 9621
#
# Total Partial NaN Values in the dataset: 9621
#
# Partial NaN Values Info:
#        Columns  Partial_NaN_Count  NaN_Vals_By_Total_Vals
# 0         cars               3207                   0.035
# 1  motorcycles               3207                   0.035
# 2       others               3207                   0.035
#
# Total NaN Values/Total Datset Values: 1.74 %

# %% [markdown]
# #### 2021 data doesn't have q4 data, hence those values are nan. For now the values are imputed with -1.

# %%
df.loc[(df['year'] == '2021') & (df['quarter'] == '4'), ['cars', 'motorcycles', 'others']] = -1
df.loc[(df['year'] == '2021') & (df['quarter'] == '4')]
# Out:
#       cars motorcycles others postcode_district  year quarter
# 69066   -1          -1     -1               AB1  2021       4
# 69067   -1          -1     -1              AB10  2021       4
# 69068   -1          -1     -1              AB11  2021       4
# 69069   -1          -1     -1              AB12  2021       4
# 69070   -1          -1     -1              AB13  2021       4
# ...    ...         ...    ...               ...   ...     ...
# 71945   -1          -1     -1               YO8  2021       4
# 71946   -1          -1     -1              YO91  2021       4
# 71947   -1          -1     -1               ZE1  2021       4
# 71948   -1          -1     -1               ZE2  2021       4
# 71949   -1          -1     -1               ZE3  2021       4
#
# [2884 rows x 6 columns]

# %%
nan = Preprocessing.NanAnalyzer(df)
nan.printNaNInfo()
# Out:
# NAN INFO IN THE DATASET:
#
# No of columns with only NaN values: 0
# Column list with only NaN values:
# []
#
# No of columns with partial NaN values: 3
# Column list with partial NaN values:
# ['cars', 'motorcycles', 'others']
#
# No of columns with no NaN values: 3
# Column list with no NaN values:
# ['postcode_district', 'year', 'quarter']
#
# Total Values in dataset: 552528
#
# Total NaN Values in the dataset: 969
#
# Total Partial NaN Values in the dataset: 969
#
# Partial NaN Values Info:
#        Columns  Partial_NaN_Count  NaN_Vals_By_Total_Vals
# 0         cars                323                   0.004
# 1  motorcycles                323                   0.004
# 2       others                323                   0.004
#
# Total NaN Values/Total Datset Values: 0.18 %

# %%
df = df.drop(df[df['cars'].isnull() & df['motorcycles'].isnull() & df['others'].isnull()].index).reset_index(drop=True)

# %%
nan = Preprocessing.NanAnalyzer(df)
nan.printNaNInfo()
del nan
# Out:
# NAN INFO IN THE DATASET:
#
# No of columns with only NaN values: 0
# Column list with only NaN values:
# []
#
# No of columns with partial NaN values: 0
# Column list with partial NaN values:
# []
#
# No of columns with no NaN values: 6
# Column list with no NaN values:
# ['cars', 'motorcycles', 'others', 'postcode_district', 'year', 'quarter']
#
# Total Values in dataset: 550590
#
# Total NaN Values in the dataset: 0
#
# Total Partial NaN Values in the dataset: 0
#
# Partial NaN Values Info:
# Empty DataFrame
# Columns: [Columns, Partial_NaN_Count, NaN_Vals_By_Total_Vals]
# Index: []
#
# Total NaN Values/Total Datset Values: 0.0 %

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91765 entries, 0 to 91764
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cars               91765 non-null  object
#  1   motorcycles        91765 non-null  object
#  2   others             91765 non-null  object
#  3   postcode_district  91765 non-null  object
#  4   year               91765 non-null  object
#  5   quarter            91765 non-null  object
# dtypes: object(6)
# memory usage: 4.2+ MB
#    cars motorcycles others postcode_district  year quarter
# 0    23          12      7               AB1  2021       1
# 1   519         235     93              AB10  2021       1
# 2   550         212    187              AB11  2021       1
# 3  1175         467    720              AB12  2021       1
# 4   143          51     28              AB13  2021       1

# %% [markdown]
# ## DataType Check

# %%
{c: '' for c in df.columns}
# Out:
# {'cars': '',
#  'motorcycles': '',
#  'others': '',
#  'postcode_district': '',
#  'year': '',
#  'quarter': ''}

# %%
dtype_mapper = {'cars': 'int64',
                'motorcycles': 'int64',
                'others': 'int64',
                'year': 'int64',
                'postcode_district': 'str',
                'quarter': 'int64'}

# %%
dta = Preprocessing.DataTypeAnalyzer()

dta.findUnExpectedDtypeValues(df, dtype_mapper)
# Out:
#              Columns ExpectedDtype MismatchedValues
# 0               cars         int64              [c]
# 1        motorcycles         int64              [c]
# 2             others         int64              [c]
# 3               year         int64               []
# 4  postcode_district           str               []
# 5            quarter         int64               []

# %% [markdown]
# #### To convert dataframe with desired datatypes we only need to handle 'c' values which signifies that the number of vehicles registered at that postcode or district is very low. So imputing c with 1 to signify low count.

# %%
for col in ['cars', 'motorcycles', 'others']:
    df[col].replace({'c':1}, inplace=True)

# %%
dta.findUnExpectedDtypeValues(df, dtype_mapper)
# Out:
#              Columns ExpectedDtype MismatchedValues
# 0               cars         int64               []
# 1        motorcycles         int64               []
# 2             others         int64               []
# 3               year         int64               []
# 4  postcode_district           str               []
# 5            quarter         int64               []

# %%
df = dta.convertDtypes(df, {k:v if v != 'str' else 'object' for k, v in dtype_mapper.items()}).reset_index(drop=True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91765 entries, 0 to 91764
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cars               91765 non-null  int64
#  1   motorcycles        91765 non-null  int64
#  2   others             91765 non-null  int64
#  3   postcode_district  91765 non-null  object
#  4   year               91765 non-null  int64
#  5   quarter            91765 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 4.2+ MB
#    cars  motorcycles  others postcode_district  year  quarter
# 0    23           12       7               AB1  2021        1
# 1   519          235      93              AB10  2021        1
# 2   550          212     187              AB11  2021        1
# 3  1175          467     720              AB12  2021        1
# 4   143           51      28              AB13  2021        1

# %% [markdown]
# ## Duplicates

# %%
Preprocessing.DuplicateAnalyzer(df, df.columns.tolist()).printDuplicateInfo()
# Out:
# Matching columns count: 0
#
# Matching columns dict:
# {}
#
# Duplicate Row count: 0
#
# DUplicate Rows:
# Empty DataFrame
# Columns: [cars, motorcycles, others, postcode_district, year, quarter]
# Index: []

# %% [markdown]
# ## Finalizing and Saving

# %%
df.head(10)
# Out:
#    cars  motorcycles  others postcode_district  year  quarter
# 0    23           12       7               AB1  2021        1
# 1   519          235      93              AB10  2021        1
# 2   550          212     187              AB11  2021        1
# 3  1175          467     720              AB12  2021        1
# 4   143           51      28              AB13  2021        1
# 5   174          113      54              AB14  2021        1
# 6  1090          521     223              AB15  2021        1
# 7   962          344     227              AB16  2021        1
# 8    16            8       1               AB2  2021        1
# 9  1215          566     605              AB21  2021        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91765 entries, 0 to 91764
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cars               91765 non-null  int64
#  1   motorcycles        91765 non-null  int64
#  2   others             91765 non-null  int64
#  3   postcode_district  91765 non-null  object
#  4   year               91765 non-null  int64
#  5   quarter            91765 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 4.2+ MB

# %%
df.agg(['count', 'min', 'max'])
# Out:
#         cars  motorcycles  others postcode_district   year  quarter
# count  91765        91765   91765             91765  91765    91765
# min       -1           -1      -1               AB1   2014        1
# max    12977         4131    3530               ZE3   2021        4

# %%
"/".join(project_dir.split("/")[:-1]) + "/vehicles_with_a_sorn_by_postcode_district_and_body_type.csv"
# Out:
# '/Users/gurdeep/Documents/tb2/DSMP/vehicles_with_a_sorn_by_postcode_district_and_body_type.csv'

# %%
df.to_csv("/".join(project_dir.split("/")[:-1]) + "/vehicles_with_a_sorn_by_postcode_district_and_body_type.csv", index=False)
