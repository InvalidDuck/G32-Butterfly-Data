# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
count_points=pd.read_csv('C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/Traffic Datasets/Bristol Traffic Data/Count points(Count points in City of Bristol).csv')

# %%
count_points
# Out:
#      count_point_id  region_id region_name  local_authority_id  \
# 0            996519          1  South West                 144
# 1            990510          1  South West                 144
# 2            990069          1  South West                 144
# 3            990068          1  South West                 144
# 4            979124          1  South West                 144
# ..              ...        ...         ...                 ...
# 253            7841          1  South West                 144
# 254            7617          1  South West                 144
# 255            7097          1  South West                 144
# 256            7046          1  South West                 144
# 257            6401          1  South West                 144
#
#     local_authority_name road_name road_type   start_junction_road_name  \
# 0       Bristol, City of         C     Minor                        NaN
# ...

# %% [markdown]
# Checking info about the dataset:

# %%
count_points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   count_point_id            258 non-null    int64
#  1   region_id                 258 non-null    int64
#  2   region_name               258 non-null    object
#  3   local_authority_id        258 non-null    int64
#  4   local_authority_name      258 non-null    object
#  5   road_name                 258 non-null    object
#  6   road_type                 258 non-null    object
#  7   start_junction_road_name  109 non-null    object
#  8   end_junction_road_name    109 non-null    object
#  9   easting                   258 non-null    int64
#  10  northing                  258 non-null    int64
#  11  latitude                  258 non-null    float64
#  12  longitude                 258 non-null    float64
# ...

# %% [markdown]
# Checking null values:

# %%
count_points.isnull().any()
# Out:
# count_point_id              False
# region_id                   False
# region_name                 False
# local_authority_id          False
# local_authority_name        False
# road_name                   False
# road_type                   False
# start_junction_road_name     True
# end_junction_road_name       True
# easting                     False
# northing                    False
# latitude                    False
# longitude                   False
# link_length_km               True
# link_length_miles            True
# dtype: bool

# %% [markdown]
# Checking for duplicates:

# %%
count_points.duplicated().any()
# Out:
# False

# %% [markdown]
# Exporting dataset as csv:

# %%
#count_points.to_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Traffic Data/count_points(City of Bristol).csv")
