# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
traffic_annual=pd.read_csv('C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/Traffic Datasets/Bristol Traffic Data/Traffic (Annual) - Copy.csv')

# %%
traffic_annual=traffic_annual.set_index("year").sort_index()

# %%
traffic_annual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 1993 to 2020
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   local_authority_id    28 non-null     int64
#  1   local_authority_name  28 non-null     object
#  2   link_length_km        28 non-null     float64
#  3   link_length_miles     28 non-null     float64
#  4   cars_and_taxis        28 non-null     int64
#  5   all_motor_vehicles    28 non-null     int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.5+ KB

# %%
traffic_annual
# Out:
#       local_authority_id local_authority_name  link_length_km  \
# year
# 1993                 144     Bristol, City of     1103.676000
# 1994                 144     Bristol, City of     1106.598000
# 1995                 144     Bristol, City of     1109.500000
# 1996                 144     Bristol, City of     1112.469000
# 1997                 144     Bristol, City of     1115.835000
# 1998                 144     Bristol, City of     1118.788000
# 1999                 144     Bristol, City of     1122.700000
# 2000                 144     Bristol, City of     1125.400000
# 2001                 144     Bristol, City of     1128.300000
# 2002                 144     Bristol, City of     1129.800000
# 2003                 144     Bristol, City of     1132.763500
# 2004                 144     Bristol, City of     1129.400000
# 2005                 144     Bristol, City of     1131.600000
# 2006                 144     Bristol, City of     1135.900000
# ...

# %%
#traffic_annual.to_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Traffic Data/traffic_annual_cleaned.csv")
