# %%
import numpy as np
import pandas as pd

# %%
traffic_data=pd.read_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Traffic Data/traffic_count_data_scoot.csv",parse_dates=['date_time'])

# %%
traffic_data_filtered=traffic_data[traffic_data['count_device_id'].isin(['107', '105', '216', '108','101','100','98','82','84','85','86','94','96','97','221','219', '222', '216','130','131','133','137'])]

# %%
traffic_data_filtered.drop(columns=['Unnamed: 0'],inplace=True)
# Out:
# C:\Users\ritun\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
traffic_data_filtered
# Out:
#          count_device_id                  date_time  hourly_flow  \
# 0                    100  2021-05-06 22:00:00+01:00          240
# 7                    219  2020-10-12 11:00:00+01:00          456
# 17                   222  2020-02-05 04:00:00+00:00            0
# 23                   130  2021-05-05 10:00:00+01:00          504
# 52                   130  2020-08-03 08:00:00+01:00          272
# ...                  ...                        ...          ...
# 8488217               97  2022-02-11 17:00:00+00:00          240
# 8488260              100  2022-02-11 22:00:00+00:00          384
# 8488276              101  2022-02-11 10:00:00+00:00          360
# 8488283              131  2022-02-11 07:00:00+00:00           64
# 8488327              137  2022-02-11 18:00:00+00:00         1632
#
#          hourly_profile                       description  \
# 0                   168     Bond St EB L2 @ Gloucester St
# 7                   368        Temple Way NB L1 @ Avon St
# ...

# %%
traffic_data_filtered_geo=traffic_data_filtered[['count_device_id','description','latitude','longitude']]

# %%
traffic_data_filtered_geo=traffic_data_filtered_geo.groupby('count_device_id', as_index=False).first()

# %%
traffic_data_filtered_geo
# Out:
#     count_device_id                       description   latitude  longitude
# 0                82      Bond St WB L3 @ Pritchard St  51.459328  -2.585054
# 1                84      Bond St WB L2 @ Pritchard St  51.459311  -2.585042
# 2                85      Bond St WB L1 @ Pritchard St  51.459296  -2.585031
# 3                86         Pritchard St SB @ Bond St  51.459893  -2.585301
# 4                94   Newfoundland Circus OB L1 @ M32  51.459949  -2.583726
# 5                96   Newfoundland Circus OB L2 @ M32  51.459946  -2.583718
# 6                97  Houlton St NB @ Newfoundland/M32  51.460210  -2.582291
# 7                98     Bond St EB L1 @ Gloucester St  51.459316  -2.586838
# 8               100     Bond St EB L2 @ Gloucester St  51.459311  -2.586840
# 9               101     Bond St EB L3 @ Gloucester St  51.459307  -2.586840
# 10              105     Temple Way SB L1 @ Old Market  51.456840  -2.584310
# ...

# %%
sensor_data=pd.read_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Pollutants/bristol_air_quality_continous.csv")
# Out:
# C:\Users\ritun\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sensor_data_filtered=sensor_data[sensor_data['site_id']==500]

# %%
sensor_data_filtered_geo=sensor_data_filtered[['site_id','location','latitude','longitude']]

# %%
sensor_data_filtered_geo=sensor_data_filtered_geo.groupby('site_id', as_index=False).first()

# %%
traffic_data_filtered_geo.rename(columns={'count_device_id':'site_id','description':'location'},inplace=True)

# %%
sensor_data_filtered_geo
# Out:
#    site_id    location  latitude  longitude
# 0      500  Temple Way  51.45795  -2.583989

# %%
traffic_data_filtered_geo
# Out:
#     site_id                          location   latitude  longitude
# 0        82      Bond St WB L3 @ Pritchard St  51.459328  -2.585054
# 1        84      Bond St WB L2 @ Pritchard St  51.459311  -2.585042
# 2        85      Bond St WB L1 @ Pritchard St  51.459296  -2.585031
# 3        86         Pritchard St SB @ Bond St  51.459893  -2.585301
# 4        94   Newfoundland Circus OB L1 @ M32  51.459949  -2.583726
# 5        96   Newfoundland Circus OB L2 @ M32  51.459946  -2.583718
# 6        97  Houlton St NB @ Newfoundland/M32  51.460210  -2.582291
# 7        98     Bond St EB L1 @ Gloucester St  51.459316  -2.586838
# 8       100     Bond St EB L2 @ Gloucester St  51.459311  -2.586840
# 9       101     Bond St EB L3 @ Gloucester St  51.459307  -2.586840
# 10      105     Temple Way SB L1 @ Old Market  51.456840  -2.584310
# 11      107     Temple Way SB L2 @ Old Market  51.456843  -2.584364
# 12      108  Temple Way SB Off Slip @ Old Mkt  51.456973  -2.584310
# ...

# %%
traffic_and_polutant_sensor_locations_temple_way=pd.concat([traffic_data_filtered_geo,sensor_data_filtered_geo])

# %%
traffic_and_polutant_sensor_locations_temple_way
# Out:
#     site_id                          location   latitude  longitude
# 0        82      Bond St WB L3 @ Pritchard St  51.459328  -2.585054
# 1        84      Bond St WB L2 @ Pritchard St  51.459311  -2.585042
# 2        85      Bond St WB L1 @ Pritchard St  51.459296  -2.585031
# 3        86         Pritchard St SB @ Bond St  51.459893  -2.585301
# 4        94   Newfoundland Circus OB L1 @ M32  51.459949  -2.583726
# 5        96   Newfoundland Circus OB L2 @ M32  51.459946  -2.583718
# 6        97  Houlton St NB @ Newfoundland/M32  51.460210  -2.582291
# 7        98     Bond St EB L1 @ Gloucester St  51.459316  -2.586838
# 8       100     Bond St EB L2 @ Gloucester St  51.459311  -2.586840
# 9       101     Bond St EB L3 @ Gloucester St  51.459307  -2.586840
# 10      105     Temple Way SB L1 @ Old Market  51.456840  -2.584310
# 11      107     Temple Way SB L2 @ Old Market  51.456843  -2.584364
# 12      108  Temple Way SB Off Slip @ Old Mkt  51.456973  -2.584310
# ...

# %%
#traffic_and_polutant_sensor_locations_temple_way.to_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Other/traffic_and_pollutant_sensor_locations_temple_way.csv",index=False)
