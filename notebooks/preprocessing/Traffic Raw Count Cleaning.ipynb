# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
traffic_raw_count=pd.read_excel('C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/Traffic Datasets/Bristol Traffic Data/Raw counts(Vehicle counts recorded at the count point).xlsx')

# %%
traffic_raw_count.drop('Unnamed: 0', inplace=True, axis=1)

# %%
traffic_raw_count
# Out:
#       count_point_id direction_of_travel  year count_date  hour  region_id  \
# 0             946787                   N  2014 2014-05-02     7          1
# 1             946787                   N  2014 2014-05-02     8          1
# 2             946787                   N  2014 2014-05-02     9          1
# 3             946787                   N  2014 2014-05-02    10          1
# 4             946787                   N  2014 2014-05-02    11          1
# ...              ...                 ...   ...        ...   ...        ...
# 9079          801247                   N  2020 2020-10-14    14          1
# 9080          801247                   N  2020 2020-10-14    15          1
# 9081          801247                   N  2020 2020-10-14    16          1
# 9082          801247                   N  2020 2020-10-14    17          1
# 9083          801247                   N  2020 2020-10-14    18          1
#
# ...

# %% [markdown]
# Checking info about the dataset:

# %%
traffic_raw_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9084 entries, 0 to 9083
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   count_point_id                9084 non-null   int64
#  1   direction_of_travel           9084 non-null   object
#  2   year                          9084 non-null   int64
#  3   count_date                    9084 non-null   datetime64[ns]
#  4   hour                          9084 non-null   int64
#  5   region_id                     9084 non-null   int64
#  6   region_name                   9084 non-null   object
#  7   local_authority_id            9084 non-null   int64
#  8   local_authority_name          9084 non-null   object
#  9   road_name                     9084 non-null   object
#  10  road_type                     9084 non-null   object
#  11  start_junction_road_name      2880 non-null   object
# ...

# %% [markdown]
# Checking null values:

# %%
traffic_raw_count.isnull().any()
# Out:
# count_point_id                  False
# direction_of_travel             False
# year                            False
# count_date                      False
# hour                            False
# region_id                       False
# region_name                     False
# local_authority_id              False
# local_authority_name            False
# road_name                       False
# road_type                       False
# start_junction_road_name         True
# end_junction_road_name           True
# easting                         False
# northing                        False
# latitude                        False
# longitude                       False
# link_length_km                   True
# link_length_miles                True
# pedal_cycles                    False
# two_wheeled_motor_vehicles      False
# cars_and_taxis                  False
# buses_and_coaches               False
# lgvs                            False
# hgvs_2_rigid_axle               False
# ...

# %% [markdown]
# Checking columns:

# %%
traffic_raw_count.columns
# Out:
# Index(['count_point_id', 'direction_of_travel', 'year', 'count_date', 'hour',
#        'region_id', 'region_name', 'local_authority_id',
#        'local_authority_name', 'road_name', 'road_type',
#        'start_junction_road_name', 'end_junction_road_name', 'easting',
#        'northing', 'latitude', 'longitude', 'link_length_km',
#        'link_length_miles', 'pedal_cycles', 'two_wheeled_motor_vehicles',
#        'cars_and_taxis', 'buses_and_coaches', 'lgvs', 'hgvs_2_rigid_axle',
#        'hgvs_3_rigid_axle', 'hgvs_4_or_more_rigid_axle',
#        'hgvs_3_or_4_articulated_axle', 'hgvs_5_articulated_axle',
#        'hgvs_6_articulated_axle', 'all_hgvs', 'all_motor_vehicles'],
#       dtype='object')

# %% [markdown]
# Checking for Duplicates:

# %%
traffic_raw_count.duplicated().any()
# Out:
# False

# %% [markdown]
# Exporting the data as CSV:

# %%
#traffic_raw_count.to_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Traffic Data/traffic_raw_count_cleaned.csv")

# %%
#BREAK

# %%
#BREAK

# %% [markdown]
# EXPLORATORY DATA ANALYSIS:

# %%
traffic_raw_count.groupby('count_date').count()
# Out:
#             count_point_id  direction_of_travel  year  hour  region_id  \
# count_date
# 2014-05-02              48                   48    48    48         48
# 2014-05-06              24                   24    24    24         24
# 2014-05-07              48                   48    48    48         48
# 2014-05-08              24                   24    24    24         24
# 2014-05-12              24                   24    24    24         24
# ...                    ...                  ...   ...   ...        ...
# 2020-09-23              24                   24    24    24         24
# 2020-09-25              24                   24    24    24         24
# 2020-10-02              24                   24    24    24         24
# 2020-10-08              24                   24    24    24         24
# 2020-10-14              24                   24    24    24         24
#
#             region_name  local_authority_id  local_authority_name  road_name  \
# count_date
# ...

# %%
pd.to_datetime(traffic_raw_count['count_date'].unique()).sort_values().tolist()
# Out:
# [Timestamp('2014-05-02 00:00:00'),
#  Timestamp('2014-05-06 00:00:00'),
#  Timestamp('2014-05-07 00:00:00'),
#  Timestamp('2014-05-08 00:00:00'),
#  Timestamp('2014-05-12 00:00:00'),
#  Timestamp('2014-05-13 00:00:00'),
#  Timestamp('2014-05-15 00:00:00'),
#  Timestamp('2014-05-16 00:00:00'),
#  Timestamp('2014-05-19 00:00:00'),
#  Timestamp('2014-05-20 00:00:00'),
#  Timestamp('2014-05-23 00:00:00'),
#  Timestamp('2014-06-02 00:00:00'),
#  Timestamp('2014-06-03 00:00:00'),
#  Timestamp('2014-06-09 00:00:00'),
#  Timestamp('2014-06-10 00:00:00'),
#  Timestamp('2014-06-11 00:00:00'),
#  Timestamp('2014-06-13 00:00:00'),
#  Timestamp('2014-06-16 00:00:00'),
#  Timestamp('2014-06-18 00:00:00'),
#  Timestamp('2014-06-20 00:00:00'),
#  Timestamp('2014-06-26 00:00:00'),
#  Timestamp('2014-06-27 00:00:00'),
#  Timestamp('2014-06-30 00:00:00'),
#  Timestamp('2014-07-02 00:00:00'),
#  Timestamp('2014-07-03 00:00:00'),
#  Timestamp('2014-09-05 00:00:00'),
#  Timestamp('2014-09-08 00:00:00'),
# ...

# %%
traffic_raw_count.groupby('count_point_id').all_motor_vehicles.mean()
# Out:
# count_point_id
# 6401      377.375000
# 7046      425.000000
# 7097      490.500000
# 7617      857.291667
# 7841      726.916667
#              ...
# 946809      5.576389
# 946813     75.750000
# 946814     14.958333
# 946820     21.666667
# 951879     10.604167
# Name: all_motor_vehicles, Length: 158, dtype: float64

# %%
traffic_raw_count.groupby('count_date')['all_motor_vehicles'].sum()
# Out:
# count_date
# 2014-05-02    1608
# 2014-05-06     808
# 2014-05-07    7222
# 2014-05-08    4684
# 2014-05-12     408
#               ...
# 2020-09-23    1139
# 2020-09-25    8056
# 2020-10-02     106
# 2020-10-08    1492
# 2020-10-14    8108
# Name: all_motor_vehicles, Length: 319, dtype: int64

# %%
traffic_raw_count.groupby('year').all_motor_vehicles.sum()
# Out:
# year
# 2014     645933
# 2015     489827
# 2016     387306
# 2017    1018399
# 2018     493589
# 2019     638939
# 2020     542855
# Name: all_motor_vehicles, dtype: int64

# %%
traffic_raw_count
# Out:
#       count_point_id direction_of_travel  year count_date  hour  region_id  \
# 0             946787                   N  2014 2014-05-02     7          1
# 1             946787                   N  2014 2014-05-02     8          1
# 2             946787                   N  2014 2014-05-02     9          1
# 3             946787                   N  2014 2014-05-02    10          1
# 4             946787                   N  2014 2014-05-02    11          1
# ...              ...                 ...   ...        ...   ...        ...
# 9079          801247                   N  2020 2020-10-14    14          1
# 9080          801247                   N  2020 2020-10-14    15          1
# 9081          801247                   N  2020 2020-10-14    16          1
# 9082          801247                   N  2020 2020-10-14    17          1
# 9083          801247                   N  2020 2020-10-14    18          1
#
# ...

# %%
traffic_raw_count.apply(lambda x: traffic_raw_count.loc[(traffic_raw_count.count_date >='2014-05-01') & (traffic_raw_count.count_date <= '2014-12-31'), 'count_date'].sum(), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-528e06cb4a01> in <module>
# ----> 1 traffic_raw_count.apply(lambda x: traffic_raw_count.loc[(traffic_raw_count.count_date >='2014-05-01') & (traffic_raw_count.count_date <= '2014-12-31'), 'count_date'].sum(), axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
# ...
