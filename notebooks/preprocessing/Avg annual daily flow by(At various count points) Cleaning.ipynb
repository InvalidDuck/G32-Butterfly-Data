# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
avg_annual_daily=pd.read_excel('C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/Traffic Datasets/Bristol Traffic Data/Average annual daily flow(At various count points).xlsx')

# %%
avg_annual_daily.drop('Unnamed: 0', inplace=True, axis=1)

# %%
avg_annual_daily
# Out:
#       count_point_id  year  region_id region_name  local_authority_id  \
# 0             946809  2014          1  South West                 144
# 1              27877  2014          1  South West                 144
# 2              27728  2014          1  South West                 144
# 3              46408  2014          1  South West                 144
# 4             946747  2014          1  South West                 144
# ...              ...   ...        ...         ...                 ...
# 1005           28726  2020          1  South West                 144
# 1006           38142  2020          1  South West                 144
# 1007           26128  2020          1  South West                 144
# 1008           28348  2020          1  South West                 144
# 1009           92038  2020          1  South West                 144
#
#      local_authority_name road_name road_type   start_junction_road_name  \
# ...

# %% [markdown]
# Checking info about the dataset:

# %%
avg_annual_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   count_point_id                1010 non-null   int64
#  1   year                          1010 non-null   int64
#  2   region_id                     1010 non-null   int64
#  3   region_name                   1010 non-null   object
#  4   local_authority_id            1010 non-null   int64
#  5   local_authority_name          1010 non-null   object
#  6   road_name                     1010 non-null   object
#  7   road_type                     1010 non-null   object
#  8   start_junction_road_name      715 non-null    object
#  9   end_junction_road_name        715 non-null    object
#  10  easting                       1010 non-null   int64
#  11  northing                      1010 non-null   int64
# ...

# %% [markdown]
# Checking null values:

# %%
avg_annual_daily.isnull().any()
# Out:
# count_point_id                  False
# year                            False
# region_id                       False
# region_name                     False
# local_authority_id              False
# local_authority_name            False
# road_name                       False
# road_type                       False
# start_junction_road_name         True
# end_junction_road_name           True
# easting                         False
# northing                        False
# latitude                        False
# longitude                       False
# link_length_km                   True
# link_length_miles                True
# estimation_method               False
# estimation_method_detailed      False
# pedal_cycles                    False
# two_wheeled_motor_vehicles      False
# cars_and_taxis                  False
# buses_and_coaches               False
# lgvs                            False
# hgvs_2_rigid_axle               False
# hgvs_3_rigid_axle               False
# ...

# %% [markdown]
# Checking for duplicates:

# %%
avg_annual_daily.duplicated().any()
# Out:
# False

# %% [markdown]
# Exporting dataset as csv:

# %%
#avg_annual_daily.to_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Traffic Data/avg_annual_daily.csv")
