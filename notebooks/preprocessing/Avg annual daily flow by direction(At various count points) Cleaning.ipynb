# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
avg_annual_daily_direc=pd.read_excel('C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/Traffic Datasets/Bristol Traffic Data/Average annual daily flow by direction(At various count points).xlsx')

# %%
avg_annual_daily_direc.drop('Unnamed: 0', inplace=True, axis=1)

# %%
avg_annual_daily_direc
# Out:
#       count_point_id  year  region_id region_name  local_authority_id  \
# 0              16959  2014          1  South West                 144
# 1             946742  2014          1  South West                 144
# 2             946742  2014          1  South West                 144
# 3             946765  2014          1  South West                 144
# 4             946765  2014          1  South West                 144
# ...              ...   ...        ...         ...                 ...
# 1863           28420  2020          1  South West                 144
# 1864           28420  2020          1  South West                 144
# 1865           36133  2020          1  South West                 144
# 1866           58285  2020          1  South West                 144
# 1867           73300  2020          1  South West                 144
#
#      local_authority_name road_name road_type  \
# 0        Bristol, City of     A3029     Major
# ...

# %% [markdown]
# Checking info about the dataset:

# %%
avg_annual_daily_direc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1868 entries, 0 to 1867
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   count_point_id                1868 non-null   int64
#  1   year                          1868 non-null   int64
#  2   region_id                     1868 non-null   int64
#  3   region_name                   1868 non-null   object
#  4   local_authority_id            1868 non-null   int64
#  5   local_authority_name          1868 non-null   object
#  6   road_name                     1868 non-null   object
#  7   road_type                     1868 non-null   object
#  8   start_junction_road_name      1279 non-null   object
#  9   end_junction_road_name        1279 non-null   object
#  10  easting                       1868 non-null   int64
#  11  northing                      1868 non-null   int64
# ...

# %% [markdown]
# Checking null values:

# %%
avg_annual_daily_direc.isnull().any()
# Out:
# count_point_id                  False
# year                            False
# region_id                       False
# region_name                     False
# local_authority_id              False
# local_authority_name            False
# road_name                       False
# road_type                       False
# start_junction_road_name         True
# end_junction_road_name           True
# easting                         False
# northing                        False
# latitude                        False
# longitude                       False
# link_length_km                   True
# link_length_miles                True
# estimation_method               False
# estimation_method_detailed      False
# direction_of_travel             False
# pedal_cycles                    False
# two_wheeled_motor_vehicles      False
# cars_and_taxis                  False
# buses_and_coaches               False
# lgvs                            False
# hgvs_2_rigid_axle               False
# ...

# %% [markdown]
# Checking for duplicates:

# %%
avg_annual_daily_direc.duplicated().any()
# Out:
# False

# %% [markdown]
# Exporting dataset as csv:

# %%
#avg_annual_daily_direc.to_csv("C:/Users/ritun/Desktop/MSc Data Science University of Bristol/Data Science Mini Project/CLEANED DATA/Traffic Data/avg_annual_daily_direc.csv")
