# %%
import pandas as pd

# %%
df = pd.read_csv("premature-mortality-by-selected-cause-in-bristol.csv", delimiter = ';')

# %%
df.head()
# Out:
#    Ward Code                   Ward Name  Time Period  \
# 0  E05010886  Avonmouth & Lawrence Weston   2013-2015
# 1  E05010897                    Eastville   2013-2015
# 2  E05010892                      Central   2014-2016
# 3  E05010900       Hartcliffe & Withywood   2014-2016
# 4  E05010914                   Southville   2014-2016
#
#    Cancer - Persons (rate per 100,000)  \
# 0                           169.600000
# 1                           119.800000
# 2                           267.167339
# 3                           215.868453
# 4                           224.234078
#
#    Cancer - Persons (Lower Confidence Limit) rate per 100,000  \
# 0                                         135.500000
# 1                                          80.700000
# 2                                         179.808902
# 3                                         171.756128
# 4                                         160.459626
#
# ...

# %%
df = df.drop(["Cancer - Persons (rate per 100,000)",
             "Cancer - Persons (Lower Confidence Limit) rate per 100,000",
              "Cancer - Persons (Upper Confidence Limit) rate per 100,000",
             "Liver Disease - Persons (rate per 100,000)",
              "Liver Disease - Persons (Upper Confidence Limit) rate per 100,000",
             "Liver Disease - Persons (Lower Confidence Limit) rate per 100,000"], axis =1)

# %%
df.head()
# Out:
#    Ward Code                   Ward Name  Time Period  \
# 0  E05010886  Avonmouth & Lawrence Weston   2013-2015
# 1  E05010897                    Eastville   2013-2015
# 2  E05010892                      Central   2014-2016
# 3  E05010900       Hartcliffe & Withywood   2014-2016
# 4  E05010914                   Southville   2014-2016
#
#    Cardiovascular Disease - Persons (rate per 100,000)  \
# 0                                          89.600000
# 1                                          99.300000
# 2                                         129.115510
# 3                                         140.615491
# 4                                         139.592097
#
#    Cardiovascular Disease - Persons (Lower Confidence Limit) rate per 100,000  \
# 0                                          65.100000
# 1                                          63.000000
# 2                                          67.354441
# 3                                         105.049538
# ...

# %%
df.shape
# Out:
# (210, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 11 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Ward Code                                                                   204 non-null    object
#  1   Ward Name                                                                   210 non-null    object
#  2   Time Period                                                                 210 non-null    object
#  3   Cardiovascular Disease - Persons (rate per 100,000)                         210 non-null    float64
#  4   Cardiovascular Disease - Persons (Lower Confidence Limit) rate per 100,000  210 non-null    float64
#  5   Cardiovascular Disease - Persons (Upper Confidence Limit) rate per 100,000  210 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Ward Code                                                                     6
# Ward Name                                                                     0
# Time Period                                                                   0
# Cardiovascular Disease - Persons (rate per 100,000)                           0
# Cardiovascular Disease - Persons (Lower Confidence Limit) rate per 100,000    0
# Cardiovascular Disease - Persons (Upper Confidence Limit) rate per 100,000    0
# Respiratory Disease -  Persons (rate per 100,000)                             0
# Respiratory Disease - Persons (Lower Confidence Limit) rate per 100,000       0
# Respiratory Disease - Persons (Upper Confidence Limit) rate per 100,000       0
# geo_shape                                                                     6
# geo_point_2d                                                                  6
# dtype: int64

# %%
df.describe()
# Out:
#        Cardiovascular Disease - Persons (rate per 100,000)  \
# count                                         210.000000
# mean                                           78.957713
# std                                            34.285116
# min                                            12.657609
# 25%                                            52.649017
# 50%                                            75.384692
# 75%                                           102.857763
# max                                           168.300000
#
#        Cardiovascular Disease - Persons (Lower Confidence Limit) rate per 100,000  \
# count                                         210.000000
# mean                                           47.603225
# std                                            26.363942
# min                                            -0.692454
# 25%                                            26.007106
# 50%                                            44.847008
# ...
